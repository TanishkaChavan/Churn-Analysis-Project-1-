# %%
Project Title: Bank Customer Churn Prediction project
           - BY TANISHKA CHAVAN.

# %%
Project Description:
The customer churn dataset is a collection of customer data that focuses on predicting customer churn, which refers to the tendency of
customers to stop using a companys products or services. The dataset contains various features that describe each customer, such as their 
credit score, country, gender, age, tenure, balance, number of products, credit card status, active membership, estimated salary, and churn status. 
The churn status indicates whether a customer has churned or not. The dataset is used to analyze and understand factors that contribute to customer
churn and to build predictive models to identify customers at risk of churning. The goal is to develop strategies and interventions to reduce churn 
and improve customer retention.

# %%
Data Description:
    The dataset contains 12 columns and 10,000 rows.
    Key features include:
      - Numerical columns: credit_score, age, tenure, balance, estimated_salary, etc.
      - Categorical columns: country, gender.
      - Target variable: churn (indicating if a customer has churned).
      -	All columns have 10,000 non-null entries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Bank Customer Churn Prediction.csv")

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# ...

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
print(df.isnull().sum())
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
numerical_column = df.select_dtypes(include=['float64', 'int64'])
categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
numerical_df
# Out:
#       customer_id  credit_score  age  tenure    balance  products_number  \
# 0        15634602           619   42       2       0.00                1
# 1        15647311           608   41       1   83807.86                1
# 2        15619304           502   42       8  159660.80                3
# 3        15701354           699   39       1       0.00                2
# 4        15737888           850   43       2  125510.82                1
# ...           ...           ...  ...     ...        ...              ...
# 9995     15606229           771   39       5       0.00                2
# 9996     15569892           516   35      10   57369.61                1
# 9997     15584532           709   36       7       0.00                1
# 9998     15682355           772   42       3   75075.31                2
# 9999     15628319           792   28       4  130142.79                1
#
#       credit_card  active_member  estimated_salary  churn
# ...

# %%
categorical_columns = df.select_dtypes(include=['object', 'category'])

# %%
categorical_columns
# Out:
#       country  gender
# 0      France  Female
# 1       Spain  Female
# 2      France  Female
# 3      France  Female
# 4       Spain  Female
# ...       ...     ...
# 9995   France    Male
# 9996   France    Male
# 9997   France  Female
# 9998  Germany    Male
# 9999   France  Female
#
# [10000 rows x 2 columns]

# %%
# Age distribution
sns.histplot(df['age'], kde=True, bins=30, color='red')
plt.title("Age Distribution")
plt.show()

# %%
# Balance distribution
sns.histplot(df['balance'], kde=True, color='green')
plt.title("Balance Distribution")
plt.show()

# %%
# Churn count
sns.countplot(x='churn', data=df, palette='Set2')
plt.title("Churn Count")
plt.xticks([0, 1], labels=['Not Churned', 'Churned'])
plt.show()

# Churn percentage
churn_rate = df['churn'].value_counts(normalize=True) * 100
print(churn_rate)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13776\2181292766.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='churn', data=df, palette='Set2')
# churn
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64

# %%
# What is the impact of age and tenure on churn?
# Age vs Churn
sns.boxplot(x='churn', y='age', data=df, palette='Set3')
plt.title("Age vs. Churn")
plt.xticks([0, 1], labels=['Not Churned', 'Churned'])
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11552\1022782958.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y='age', data=df, palette='Set3')

# %%
# Churn by Country
country_churn = pd.crosstab(df['country'], df['churn'], normalize='index') * 100
country_churn.plot(kind='bar', stacked=True, color=['pink', 'blue'], figsize=(8, 5))
plt.title("Churn by Country")
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.legend(['Not Churned', 'Churned'])
plt.show()

# Churn by Gender
sns.countplot(x='gender', hue='churn', data=df, palette='pastel')
plt.title("Churn by Gender")
plt.show()

# %%
# Define categorical columns explicitly
categorical_Columns = ['country', 'gender', 'credit_card', 'active_member', 'churn']

# If you want to identify categorical columns automatically
categorical_Columns = df.select_dtypes(include=['object']).columns.tolist()
print("Categorical Columns:", categorical_Columns)
# Out:
# Categorical Columns: ['country', 'gender']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import math

# List of numerical columns (example columns)
numerical_column = ['credit_score', 'age', 'tenure', 'balance', 'products_number', 'estimated_salary']

# Calculate rows and columns for the grid
num_plots = len(numerical_column)
rows = math.ceil(num_plots / 3)  # Dynamic calculation
cols = 3

# Set the figure size
plt.figure(figsize=(15, rows * 4))

# Loop through numerical columns and create box plots
for idx, col in enumerate(numerical_column):
    plt.subplot(rows, cols, idx + 1)  # Dynamically set grid position
    sns.boxplot(x='churn', y=col, data=df, palette='coolwarm', hue=None)  # Set `hue=None`
    plt.title(f'Boxplot of {col} by Churn')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14068\2828380459.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y=col, data=df, palette='coolwarm', hue=None)  # Set `hue=None`
# C:\Users\admin\AppData\Local\Temp\ipykernel_14068\2828380459.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y=col, data=df, palette='coolwarm', hue=None)  # Set `hue=None`
# C:\Users\admin\AppData\Local\Temp\ipykernel_14068\2828380459.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
numerical_df = df.select_dtypes(include=['float64', 'int64'])
# correlation matrix
corr_matrix = numerical_df.corr()

# %%
# heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
* Suggestions

- Personalized Services for High-Balance Customers
- Offer premium services, such as personalized financial advice to retain customers with high balances who are less likely to churn.
- Develop marketing strategies with high churn rates, such as France and Germany, to improve customer satisfaction and loyalty.

* Conclusion

- Key drivers of churn include low tenure, low balances, and specific demographics, such as younger customers and certain regions.
- Customers with high balances are more loyal, while younger customers and those in France and Germany exhibit higher churn rates.
